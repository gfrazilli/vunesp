# %%
pip install fdb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import fdb
import pandas as pd

# %%
# DatabaseName='localhost:C:\Evoltech\Dados\ESTOQUE.FDB'
# Parâmetros='user_name=SYSDBA password=masterkey'

# %%
conn = fdb.connect(
    host='localhost', database='D:/Frazilli_dash/FRAZILLI.GDB', 
    user='SYSDBA', password='masterkey')

# %%
c = conn.cursor()

# %%
query = "SELECT * FROM PED_VEND"
df = pd.read_sql(query, con=conn)
# Out:
# C:\Users\didio\AppData\Local\Temp\ipykernel_4908\2801495965.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, con=conn)

# %%
df
# Out:
#         ANO ANOORCAM          BAIRRO         CEP   CFOP  CFOP_DIF  \
# 0      2016     2016          CENTRO  18490-000   5.102  5.102-01
# 1      2016     2016          CENTRO  18440-000   5.102  5.102-01
# 2      2016     2016            None       -      5.102  5.102-01
# 3      2016     2016            None       -      5.102  5.102-01
# 4      2016     2016     V DOM BOSCO  18400-000   5.102  5.102-01
# ...     ...      ...             ...         ...    ...       ...
# 56163  2023     2023  JARDIM MARINGÁ  18407-111   5.102  5.102-01
# 56164  2023     2023          CENTRO  18400-000   5.102  5.102-01
# 56165  2023     2023      TAQUARIVAI  18402-02    5.102  5.102-01
# 56166  2023     2023      TAQUARIVAI  18402-02    5.102  5.102-01
# 56167  2023     2023  JARDIM MARINGÁ  18407-111   5.102  5.102-01
#
#                   CIDADE             CNPJCPF  CODCLI  CODCOND  ...  \
# 0      BARAO DE ANTONINA  10.494.982/0001-79   11941       36  ...
# ...

# %%
df.to_csv("vendas.csv", sep=";", decimal =',')
